# %%
# !nvidia-smi
# Out:
# Sat Dec 13 10:56:57 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   49C    P8             11W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
 data_path="/content/drive/MyDrive/chatbot_dl/chatbot_data.json"

# %%
# Step 0: Environment + imports + Colab-safe drive mount
import os
import json
import random
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD

# %%
# Colab-safe drive mount: attempt to mount if running on Colab, otherwise use cwd
try:
    import google.colab
    from google.colab import drive
    drive.mount('/content/drive')
    data_base_path = '/content/drive/MyDrive/chatbot_dl'
    print("Running on Colab. Using data_base_path =", data_base_path)
    drive.mount("/content/drive", force_remount=True)
except Exception:
    data_base_path = os.getcwd()
    print("Not running on Colab. Using current working directory as data_base_path =", data_base_path)
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Running on Colab. Using data_base_path = /content/drive/MyDrive/chatbot_dl
# Mounted at /content/drive

# %%
# Step 1: data path and NLTK downloads
data_path = os.path.join(data_base_path, 'chatbot_data.json')

if not os.path.exists(data_path):
    raise FileNotFoundError(f"Data file not found at: {data_path}\nPlease place chatbot_data.json in {data_base_path}")

# NLTK resources (download if needed)
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
# !ls -R /content/drive/MyDrive/chatbot_dl/
# Out:
# /content/drive/MyDrive/chatbot_dl/:
# chatbot_data.json

# %%
# Step 2: load JSON intents
with open(data_path, 'r', encoding='utf-8') as f:
    intents = json.load(f)

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
# Step 3: preprocessing: tokenization, lemmatization, collect words/classes/documents
lemmatizer = WordNetLemmatizer()
ignore_words = ['?', '!', '.', ',']

words = []       # all unique words (raw tokens, will lemmatize later)
classes = []     # unique intent tags
documents = []   # list of (tokenized_pattern, tag) tuples

for intent in intents.get('intents', []):
    tag = intent.get('tag')
    for pattern in intent.get('patterns', []):
        tokens = word_tokenize(pattern)
        words.extend(tokens)
        documents.append((tokens, tag))
    if tag not in classes:
        classes.append(tag)

# Lemmatize and lower-case words, remove ignored tokens, deduplicate & sort
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(set(words))
classes = sorted(set(classes))

print("Total unique words:", len(words))
print("Total classes:", len(classes))
print("Total documents:", len(documents))
# Out:
# Total unique words: 157
# Total classes: 102
# Total documents: 313

# %%
# Step 4: create bag-of-words vector function and build training set
def bag_of_words(tokenized_sentence, all_words):
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in tokenized_sentence]
    bag = [1 if w in sentence_words else 0 for w in all_words]
    return np.array(bag, dtype=int)

training = []
output_empty = [0] * len(classes)

for doc in documents:
    pattern_tokens = doc[0]
    tag = doc[1]
    bag = bag_of_words(pattern_tokens, words)
    output_row = output_empty.copy()
    output_row[classes.index(tag)] = 1
    training.append([bag, output_row])

# %%
# Step 5: shuffle and split into train_x, train_y
random.shuffle(training)

# --- FIX: use list comprehensions to extract columns (works independent of numpy shape) ---
train_x = [t[0] for t in training]
train_y = [t[1] for t in training]

train_x = np.array(train_x, dtype=float)
train_y = np.array(train_y, dtype=float)

print("train_x shape:", train_x.shape)
print("train_y shape:", train_y.shape)

VALIDATION_SET = (train_x, train_y)
# Out:
# train_x shape: (313, 157)
# train_y shape: (313, 102)

# %%
# Step 6: Create a simple feed-forward network
input_size = train_x.shape[1]
output_size = train_y.shape[1]

model = Sequential()
model.add(Dense(128, input_shape=(input_size,), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(output_size, activation='softmax'))

model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 128)            │        20,224 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 102)            │         6,630 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 35,110 (137.15 KB)
#  Trainable params: 35,110 (137.15 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Step 7: Compile the model
sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

# %%
# Step 8: Train
history = model.fit(
    train_x,
    train_y,
    epochs=350,
    batch_size=7,
    validation_split=0.2,
    verbose=1
)
# Out:
# Epoch 1/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 6s 56ms/step - accuracy: 0.0000e+00 - loss: 4.6375 - val_accuracy: 0.0000e+00 - val_loss: 4.6270
# Epoch 2/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0322 - loss: 4.6054 - val_accuracy: 0.0317 - val_loss: 4.6407
# Epoch 3/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0404 - loss: 4.5718 - val_accuracy: 0.0317 - val_loss: 4.6484
# Epoch 4/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0259 - loss: 4.5828 - val_accuracy: 0.0159 - val_loss: 4.6581
# Epoch 5/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0319 - loss: 4.5422 - val_accuracy: 0.0159 - val_loss: 4.6722
# Epoch 6/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0615 - loss: 4.4744 - val_accuracy: 0.0159 - val_loss: 4.6891
# Epoch 7/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0599 - loss: 4.4404 - val_accuracy: 0.0159 - val_loss: 4.6892
# Epoch 8/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0505 - loss: 4.3956 - val_accuracy: 0.0159 - val_loss: 4.7024
# Epoch 9/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0580 - loss: 4.3433 - val_accuracy: 0.0159 - val_loss: 4.7029
# Epoch 10/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1047 - loss: 4.2469 - val_accuracy: 0.0159 - val_loss: 4.7051
# Epoch 11/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.0960 - loss: 4.1878 - val_accuracy: 0.0159 - val_loss: 4.6941
# Epoch 12/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1035 - loss: 4.1751 - val_accuracy: 0.0159 - val_loss: 4.6673
# Epoch 13/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1129 - loss: 4.1815 - val_accuracy: 0.0159 - val_loss: 4.5804
# Epoch 14/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1766 - loss: 3.8774 - val_accuracy: 0.0317 - val_loss: 4.5532
# Epoch 15/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2406 - loss: 3.7245 - val_accuracy: 0.0635 - val_loss: 4.4612
# Epoch 16/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2004 - loss: 3.7031 - val_accuracy: 0.0635 - val_loss: 4.3967
# Epoch 17/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.1964 - loss: 3.6102 - val_accuracy: 0.0952 - val_loss: 4.2916
# Epoch 18/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3069 - loss: 3.3019 - val_accuracy: 0.1429 - val_loss: 4.1714
# Epoch 19/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2915 - loss: 3.2602 - val_accuracy: 0.1429 - val_loss: 4.0269
# Epoch 20/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3406 - loss: 3.0540 - val_accuracy: 0.2222 - val_loss: 3.9056
# Epoch 21/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3892 - loss: 2.7124 - val_accuracy: 0.2698 - val_loss: 3.7325
# Epoch 22/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.2995 - loss: 2.9041 - val_accuracy: 0.3492 - val_loss: 3.5866
# Epoch 23/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3548 - loss: 2.7077 - val_accuracy: 0.3810 - val_loss: 3.4444
# Epoch 24/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4311 - loss: 2.3964 - val_accuracy: 0.4444 - val_loss: 3.2698
# Epoch 25/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4293 - loss: 2.4488 - val_accuracy: 0.4762 - val_loss: 3.1398
# Epoch 26/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5097 - loss: 2.2764 - val_accuracy: 0.5556 - val_loss: 2.9914
# Epoch 27/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.4995 - loss: 2.2131 - val_accuracy: 0.5873 - val_loss: 2.8575
# Epoch 28/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5212 - loss: 2.1271 - val_accuracy: 0.5556 - val_loss: 2.7449
# Epoch 29/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5203 - loss: 2.1243 - val_accuracy: 0.6508 - val_loss: 2.6076
# Epoch 30/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5489 - loss: 1.8690 - val_accuracy: 0.6349 - val_loss: 2.4569
# Epoch 31/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5446 - loss: 1.9493 - val_accuracy: 0.6190 - val_loss: 2.3526
# Epoch 32/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5018 - loss: 2.0805 - val_accuracy: 0.6032 - val_loss: 2.3171
# Epoch 33/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5646 - loss: 1.7280 - val_accuracy: 0.6032 - val_loss: 2.1948
# Epoch 34/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5892 - loss: 1.6655 - val_accuracy: 0.6190 - val_loss: 2.1158
# Epoch 35/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6051 - loss: 1.6346 - val_accuracy: 0.6349 - val_loss: 1.9791
# Epoch 36/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6180 - loss: 1.6722 - val_accuracy: 0.6349 - val_loss: 2.0007
# Epoch 37/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6542 - loss: 1.5045 - val_accuracy: 0.7143 - val_loss: 1.8663
# Epoch 38/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6606 - loss: 1.3470 - val_accuracy: 0.6984 - val_loss: 1.7181
# Epoch 39/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6422 - loss: 1.2915 - val_accuracy: 0.7778 - val_loss: 1.6684
# Epoch 40/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6165 - loss: 1.5211 - val_accuracy: 0.8095 - val_loss: 1.5790
# Epoch 41/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6699 - loss: 1.2825 - val_accuracy: 0.8254 - val_loss: 1.5336
# Epoch 42/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6946 - loss: 1.1481 - val_accuracy: 0.7778 - val_loss: 1.4718
# Epoch 43/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6788 - loss: 1.1759 - val_accuracy: 0.7619 - val_loss: 1.4695
# Epoch 44/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6904 - loss: 1.1771 - val_accuracy: 0.8095 - val_loss: 1.3872
# Epoch 45/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7390 - loss: 1.1837 - val_accuracy: 0.8095 - val_loss: 1.3409
# Epoch 46/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.6770 - loss: 1.1665 - val_accuracy: 0.8730 - val_loss: 1.2732
# Epoch 47/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7112 - loss: 1.1507 - val_accuracy: 0.8413 - val_loss: 1.2502
# Epoch 48/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7156 - loss: 1.0106 - val_accuracy: 0.8095 - val_loss: 1.2092
# Epoch 49/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7281 - loss: 1.0598 - val_accuracy: 0.8571 - val_loss: 1.1617
# Epoch 50/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6805 - loss: 1.0754 - val_accuracy: 0.8571 - val_loss: 1.1153
# Epoch 51/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7008 - loss: 1.1328 - val_accuracy: 0.8254 - val_loss: 1.1211
# Epoch 52/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8072 - loss: 0.8477 - val_accuracy: 0.8889 - val_loss: 1.0215
# Epoch 53/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7250 - loss: 0.9960 - val_accuracy: 0.8571 - val_loss: 1.0026
# Epoch 54/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7464 - loss: 0.9228 - val_accuracy: 0.8889 - val_loss: 1.0103
# Epoch 55/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8038 - loss: 0.8873 - val_accuracy: 0.8730 - val_loss: 0.9361
# Epoch 56/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8036 - loss: 0.8498 - val_accuracy: 0.9048 - val_loss: 0.9018
# Epoch 57/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7416 - loss: 0.9848 - val_accuracy: 0.9365 - val_loss: 0.8730
# Epoch 58/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7421 - loss: 0.8599 - val_accuracy: 0.9048 - val_loss: 0.8574
# Epoch 59/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8028 - loss: 0.7705 - val_accuracy: 0.8571 - val_loss: 0.8615
# Epoch 60/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7965 - loss: 0.7316 - val_accuracy: 0.8730 - val_loss: 0.8184
# Epoch 61/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7786 - loss: 0.7956 - val_accuracy: 0.9206 - val_loss: 0.7762
# Epoch 62/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7910 - loss: 0.7341 - val_accuracy: 0.9524 - val_loss: 0.7747
# Epoch 63/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7602 - loss: 0.8282 - val_accuracy: 0.9524 - val_loss: 0.7305
# Epoch 64/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8769 - loss: 0.5911 - val_accuracy: 0.9206 - val_loss: 0.6970
# Epoch 65/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7546 - loss: 0.7578 - val_accuracy: 0.9524 - val_loss: 0.6935
# Epoch 66/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8225 - loss: 0.6626 - val_accuracy: 0.9524 - val_loss: 0.6958
# Epoch 67/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7887 - loss: 0.7880 - val_accuracy: 0.9206 - val_loss: 0.6784
# Epoch 68/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8736 - loss: 0.6164 - val_accuracy: 0.9365 - val_loss: 0.6537
# Epoch 69/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7502 - loss: 0.8917 - val_accuracy: 0.9524 - val_loss: 0.6397
# Epoch 70/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8289 - loss: 0.6696 - val_accuracy: 0.9524 - val_loss: 0.6211
# Epoch 71/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8306 - loss: 0.5938 - val_accuracy: 0.9365 - val_loss: 0.6247
# Epoch 72/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7908 - loss: 0.7279 - val_accuracy: 0.9524 - val_loss: 0.6228
# Epoch 73/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8043 - loss: 0.6800 - val_accuracy: 0.9524 - val_loss: 0.6089
# Epoch 74/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7728 - loss: 0.7621 - val_accuracy: 0.9524 - val_loss: 0.6142
# Epoch 75/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7818 - loss: 0.6566 - val_accuracy: 0.9365 - val_loss: 0.6202
# Epoch 76/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8687 - loss: 0.5714 - val_accuracy: 0.9365 - val_loss: 0.5948
# Epoch 77/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8287 - loss: 0.5610 - val_accuracy: 0.9524 - val_loss: 0.5389
# Epoch 78/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8135 - loss: 0.5245 - val_accuracy: 0.9524 - val_loss: 0.5429
# Epoch 79/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8449 - loss: 0.5552 - val_accuracy: 0.9524 - val_loss: 0.5596
# Epoch 80/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8212 - loss: 0.6051 - val_accuracy: 0.9524 - val_loss: 0.5442
# Epoch 81/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8733 - loss: 0.5735 - val_accuracy: 0.9524 - val_loss: 0.5443
# Epoch 82/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8466 - loss: 0.6096 - val_accuracy: 0.9524 - val_loss: 0.5714
# Epoch 83/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8545 - loss: 0.5612 - val_accuracy: 0.9524 - val_loss: 0.4962
# Epoch 84/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8198 - loss: 0.5759 - val_accuracy: 0.9524 - val_loss: 0.5299
# Epoch 85/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8660 - loss: 0.5460 - val_accuracy: 0.9365 - val_loss: 0.5159
# Epoch 86/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8263 - loss: 0.6064 - val_accuracy: 0.9524 - val_loss: 0.5171
# Epoch 87/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7398 - loss: 0.7547 - val_accuracy: 0.9524 - val_loss: 0.5141
# Epoch 88/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8691 - loss: 0.5128 - val_accuracy: 0.9524 - val_loss: 0.5083
# Epoch 89/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8543 - loss: 0.5544 - val_accuracy: 0.9524 - val_loss: 0.4621
# Epoch 90/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8470 - loss: 0.5123 - val_accuracy: 0.9524 - val_loss: 0.4578
# Epoch 91/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7985 - loss: 0.5859 - val_accuracy: 0.9524 - val_loss: 0.4558
# Epoch 92/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8366 - loss: 0.5282 - val_accuracy: 0.9524 - val_loss: 0.4579
# Epoch 93/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9054 - loss: 0.4068 - val_accuracy: 0.9524 - val_loss: 0.4529
# Epoch 94/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8992 - loss: 0.4434 - val_accuracy: 0.9524 - val_loss: 0.4325
# Epoch 95/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8239 - loss: 0.5381 - val_accuracy: 0.9524 - val_loss: 0.4251
# Epoch 96/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8891 - loss: 0.5478 - val_accuracy: 0.9524 - val_loss: 0.4369
# Epoch 97/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8193 - loss: 0.6461 - val_accuracy: 0.9524 - val_loss: 0.4452
# Epoch 98/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8482 - loss: 0.5600 - val_accuracy: 0.9524 - val_loss: 0.4207
# Epoch 99/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8815 - loss: 0.4280 - val_accuracy: 0.9524 - val_loss: 0.4314
# Epoch 100/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8266 - loss: 0.5228 - val_accuracy: 0.9524 - val_loss: 0.4407
# Epoch 101/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8709 - loss: 0.3865 - val_accuracy: 0.9524 - val_loss: 0.4337
# Epoch 102/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8451 - loss: 0.5126 - val_accuracy: 0.9524 - val_loss: 0.4232
# Epoch 103/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8443 - loss: 0.6380 - val_accuracy: 0.9524 - val_loss: 0.4306
# Epoch 104/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8542 - loss: 0.4977 - val_accuracy: 0.9524 - val_loss: 0.4315
# Epoch 105/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8205 - loss: 0.5495 - val_accuracy: 0.9524 - val_loss: 0.4269
# Epoch 106/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8660 - loss: 0.4699 - val_accuracy: 0.9524 - val_loss: 0.4048
# Epoch 107/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8554 - loss: 0.4244 - val_accuracy: 0.9524 - val_loss: 0.4101
# Epoch 108/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8371 - loss: 0.5874 - val_accuracy: 0.9524 - val_loss: 0.4158
# Epoch 109/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8867 - loss: 0.3812 - val_accuracy: 0.9524 - val_loss: 0.4044
# Epoch 110/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8210 - loss: 0.5845 - val_accuracy: 0.9524 - val_loss: 0.3918
# Epoch 111/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8394 - loss: 0.6461 - val_accuracy: 0.9524 - val_loss: 0.3986
# Epoch 112/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8219 - loss: 0.5457 - val_accuracy: 0.9524 - val_loss: 0.4132
# Epoch 113/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.7936 - loss: 0.6212 - val_accuracy: 0.9524 - val_loss: 0.3913
# Epoch 114/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8745 - loss: 0.4134 - val_accuracy: 0.9524 - val_loss: 0.3921
# Epoch 115/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7857 - loss: 0.7632 - val_accuracy: 0.9524 - val_loss: 0.4031
# Epoch 116/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8497 - loss: 0.4538 - val_accuracy: 0.9524 - val_loss: 0.3940
# Epoch 117/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8887 - loss: 0.4930 - val_accuracy: 0.9524 - val_loss: 0.3987
# Epoch 118/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8094 - loss: 0.6126 - val_accuracy: 0.9524 - val_loss: 0.3753
# Epoch 119/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.8371 - loss: 0.4547 - val_accuracy: 0.9524 - val_loss: 0.3908
# Epoch 120/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8954 - loss: 0.3077 - val_accuracy: 0.9524 - val_loss: 0.3886
# Epoch 121/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9032 - loss: 0.4141 - val_accuracy: 0.9524 - val_loss: 0.3660
# Epoch 122/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8386 - loss: 0.5246 - val_accuracy: 0.9524 - val_loss: 0.3833
# Epoch 123/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8660 - loss: 0.4064 - val_accuracy: 0.9524 - val_loss: 0.3710
# Epoch 124/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9022 - loss: 0.3648 - val_accuracy: 0.9524 - val_loss: 0.3689
# Epoch 125/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8372 - loss: 0.4826 - val_accuracy: 0.9524 - val_loss: 0.3673
# Epoch 126/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8516 - loss: 0.4364 - val_accuracy: 0.9524 - val_loss: 0.3761
# Epoch 127/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8649 - loss: 0.4339 - val_accuracy: 0.9524 - val_loss: 0.3860
# Epoch 128/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8788 - loss: 0.4463 - val_accuracy: 0.9524 - val_loss: 0.3870
# Epoch 129/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8569 - loss: 0.3572 - val_accuracy: 0.9524 - val_loss: 0.3807
# Epoch 130/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9011 - loss: 0.3742 - val_accuracy: 0.9524 - val_loss: 0.3530
# Epoch 131/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8346 - loss: 0.4922 - val_accuracy: 0.9524 - val_loss: 0.3457
# Epoch 132/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8968 - loss: 0.3281 - val_accuracy: 0.9524 - val_loss: 0.3562
# Epoch 133/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9239 - loss: 0.2374 - val_accuracy: 0.9524 - val_loss: 0.3519
# Epoch 134/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8729 - loss: 0.4017 - val_accuracy: 0.9524 - val_loss: 0.3565
# Epoch 135/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8800 - loss: 0.4423 - val_accuracy: 0.9524 - val_loss: 0.3379
# Epoch 136/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8553 - loss: 0.4788 - val_accuracy: 0.9365 - val_loss: 0.3813
# Epoch 137/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9209 - loss: 0.2756 - val_accuracy: 0.9524 - val_loss: 0.3689
# Epoch 138/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9211 - loss: 0.2996 - val_accuracy: 0.9524 - val_loss: 0.3693
# Epoch 139/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8690 - loss: 0.3943 - val_accuracy: 0.9524 - val_loss: 0.3717
# Epoch 140/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8628 - loss: 0.4294 - val_accuracy: 0.9524 - val_loss: 0.3619
# Epoch 141/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9017 - loss: 0.3008 - val_accuracy: 0.9524 - val_loss: 0.3544
# Epoch 142/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8985 - loss: 0.3993 - val_accuracy: 0.9524 - val_loss: 0.3523
# Epoch 143/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9055 - loss: 0.3885 - val_accuracy: 0.9524 - val_loss: 0.3627
# Epoch 144/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8039 - loss: 0.5512 - val_accuracy: 0.9524 - val_loss: 0.3413
# Epoch 145/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9062 - loss: 0.2967 - val_accuracy: 0.9524 - val_loss: 0.3672
# Epoch 146/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8473 - loss: 0.4813 - val_accuracy: 0.9524 - val_loss: 0.3522
# Epoch 147/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8817 - loss: 0.4587 - val_accuracy: 0.9524 - val_loss: 0.3548
# Epoch 148/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8510 - loss: 0.5484 - val_accuracy: 0.9524 - val_loss: 0.3319
# Epoch 149/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8696 - loss: 0.4179 - val_accuracy: 0.9524 - val_loss: 0.3475
# Epoch 150/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8923 - loss: 0.4098 - val_accuracy: 0.9524 - val_loss: 0.3532
# Epoch 151/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8760 - loss: 0.4314 - val_accuracy: 0.9524 - val_loss: 0.3518
# Epoch 152/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9186 - loss: 0.2752 - val_accuracy: 0.9524 - val_loss: 0.3451
# Epoch 153/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8947 - loss: 0.3239 - val_accuracy: 0.9524 - val_loss: 0.3514
# Epoch 154/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8766 - loss: 0.3267 - val_accuracy: 0.9524 - val_loss: 0.3746
# Epoch 155/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8788 - loss: 0.4251 - val_accuracy: 0.9524 - val_loss: 0.3472
# Epoch 156/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9253 - loss: 0.2498 - val_accuracy: 0.9524 - val_loss: 0.3448
# Epoch 157/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9229 - loss: 0.2922 - val_accuracy: 0.9524 - val_loss: 0.3377
# Epoch 158/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8709 - loss: 0.3931 - val_accuracy: 0.9524 - val_loss: 0.3443
# Epoch 159/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8530 - loss: 0.4087 - val_accuracy: 0.9524 - val_loss: 0.3347
# Epoch 160/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8742 - loss: 0.4358 - val_accuracy: 0.9524 - val_loss: 0.3397
# Epoch 161/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8417 - loss: 0.4536 - val_accuracy: 0.9524 - val_loss: 0.3419
# Epoch 162/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8489 - loss: 0.4597 - val_accuracy: 0.9524 - val_loss: 0.3310
# Epoch 163/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8731 - loss: 0.4184 - val_accuracy: 0.9524 - val_loss: 0.3385
# Epoch 164/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8086 - loss: 0.5695 - val_accuracy: 0.9524 - val_loss: 0.3284
# Epoch 165/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8680 - loss: 0.3733 - val_accuracy: 0.9524 - val_loss: 0.3542
# Epoch 166/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8891 - loss: 0.3608 - val_accuracy: 0.9524 - val_loss: 0.3377
# Epoch 167/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8895 - loss: 0.2938 - val_accuracy: 0.9524 - val_loss: 0.3268
# Epoch 168/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8451 - loss: 0.3445 - val_accuracy: 0.9524 - val_loss: 0.3273
# Epoch 169/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8363 - loss: 0.5080 - val_accuracy: 0.9524 - val_loss: 0.3191
# Epoch 170/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8841 - loss: 0.4276 - val_accuracy: 0.9524 - val_loss: 0.3231
# Epoch 171/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8806 - loss: 0.4109 - val_accuracy: 0.9524 - val_loss: 0.3360
# Epoch 172/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9028 - loss: 0.2967 - val_accuracy: 0.9524 - val_loss: 0.3301
# Epoch 173/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8034 - loss: 0.5622 - val_accuracy: 0.9524 - val_loss: 0.3300
# Epoch 174/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8851 - loss: 0.3884 - val_accuracy: 0.9524 - val_loss: 0.3174
# Epoch 175/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9303 - loss: 0.2592 - val_accuracy: 0.9524 - val_loss: 0.3369
# Epoch 176/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8765 - loss: 0.3009 - val_accuracy: 0.9524 - val_loss: 0.3383
# Epoch 177/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8848 - loss: 0.3396 - val_accuracy: 0.9524 - val_loss: 0.3468
# Epoch 178/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9145 - loss: 0.3078 - val_accuracy: 0.9524 - val_loss: 0.3365
# Epoch 179/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8747 - loss: 0.3505 - val_accuracy: 0.9524 - val_loss: 0.3373
# Epoch 180/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8878 - loss: 0.4132 - val_accuracy: 0.9524 - val_loss: 0.3403
# Epoch 181/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8800 - loss: 0.4207 - val_accuracy: 0.9524 - val_loss: 0.3347
# Epoch 182/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9128 - loss: 0.2870 - val_accuracy: 0.9524 - val_loss: 0.3439
# Epoch 183/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8209 - loss: 0.5769 - val_accuracy: 0.9524 - val_loss: 0.3510
# Epoch 184/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8411 - loss: 0.4661 - val_accuracy: 0.9524 - val_loss: 0.3355
# Epoch 185/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8704 - loss: 0.3986 - val_accuracy: 0.9524 - val_loss: 0.3296
# Epoch 186/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9273 - loss: 0.2908 - val_accuracy: 0.9524 - val_loss: 0.3249
# Epoch 187/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8986 - loss: 0.3880 - val_accuracy: 0.9524 - val_loss: 0.3237
# Epoch 188/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8827 - loss: 0.3799 - val_accuracy: 0.9524 - val_loss: 0.3496
# Epoch 189/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9170 - loss: 0.3748 - val_accuracy: 0.9524 - val_loss: 0.3423
# Epoch 190/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8835 - loss: 0.3952 - val_accuracy: 0.9524 - val_loss: 0.3411
# Epoch 191/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8758 - loss: 0.3484 - val_accuracy: 0.9524 - val_loss: 0.3122
# Epoch 192/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9404 - loss: 0.2970 - val_accuracy: 0.9524 - val_loss: 0.3154
# Epoch 193/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8718 - loss: 0.3712 - val_accuracy: 0.9524 - val_loss: 0.3362
# Epoch 194/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9088 - loss: 0.2659 - val_accuracy: 0.9524 - val_loss: 0.3159
# Epoch 195/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9212 - loss: 0.2975 - val_accuracy: 0.9524 - val_loss: 0.3196
# Epoch 196/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8925 - loss: 0.3897 - val_accuracy: 0.9524 - val_loss: 0.3314
# Epoch 197/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8739 - loss: 0.3728 - val_accuracy: 0.9524 - val_loss: 0.3344
# Epoch 198/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8482 - loss: 0.4318 - val_accuracy: 0.9524 - val_loss: 0.3316
# Epoch 199/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9034 - loss: 0.3540 - val_accuracy: 0.9524 - val_loss: 0.3314
# Epoch 200/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8959 - loss: 0.3594 - val_accuracy: 0.9524 - val_loss: 0.3102
# Epoch 201/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9065 - loss: 0.3162 - val_accuracy: 0.9524 - val_loss: 0.3108
# Epoch 202/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9160 - loss: 0.2469 - val_accuracy: 0.9524 - val_loss: 0.3279
# Epoch 203/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8800 - loss: 0.3441 - val_accuracy: 0.9524 - val_loss: 0.3160
# Epoch 204/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9284 - loss: 0.1997 - val_accuracy: 0.9524 - val_loss: 0.3203
# Epoch 205/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9080 - loss: 0.2662 - val_accuracy: 0.9524 - val_loss: 0.3223
# Epoch 206/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8342 - loss: 0.4666 - val_accuracy: 0.9524 - val_loss: 0.3286
# Epoch 207/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9077 - loss: 0.3522 - val_accuracy: 0.9524 - val_loss: 0.3151
# Epoch 208/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8532 - loss: 0.4820 - val_accuracy: 0.9524 - val_loss: 0.3168
# Epoch 209/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8938 - loss: 0.3178 - val_accuracy: 0.9524 - val_loss: 0.3178
# Epoch 210/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8399 - loss: 0.5204 - val_accuracy: 0.9524 - val_loss: 0.3126
# Epoch 211/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9155 - loss: 0.3010 - val_accuracy: 0.9524 - val_loss: 0.3134
# Epoch 212/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8925 - loss: 0.3983 - val_accuracy: 0.9524 - val_loss: 0.3142
# Epoch 213/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8776 - loss: 0.3948 - val_accuracy: 0.9524 - val_loss: 0.3099
# Epoch 214/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9379 - loss: 0.2282 - val_accuracy: 0.9524 - val_loss: 0.3116
# Epoch 215/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8843 - loss: 0.3644 - val_accuracy: 0.9524 - val_loss: 0.3060
# Epoch 216/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8424 - loss: 0.4528 - val_accuracy: 0.9524 - val_loss: 0.3172
# Epoch 217/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8839 - loss: 0.3600 - val_accuracy: 0.9524 - val_loss: 0.3120
# Epoch 218/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9232 - loss: 0.2730 - val_accuracy: 0.9524 - val_loss: 0.3066
# Epoch 219/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8572 - loss: 0.5774 - val_accuracy: 0.9524 - val_loss: 0.3007
# Epoch 220/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9123 - loss: 0.3382 - val_accuracy: 0.9524 - val_loss: 0.3049
# Epoch 221/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8905 - loss: 0.3645 - val_accuracy: 0.9524 - val_loss: 0.3128
# Epoch 222/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9142 - loss: 0.2733 - val_accuracy: 0.9524 - val_loss: 0.3113
# Epoch 223/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9084 - loss: 0.3619 - val_accuracy: 0.9524 - val_loss: 0.3039
# Epoch 224/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9321 - loss: 0.2358 - val_accuracy: 0.9524 - val_loss: 0.3140
# Epoch 225/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9056 - loss: 0.4348 - val_accuracy: 0.9524 - val_loss: 0.3119
# Epoch 226/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9042 - loss: 0.3382 - val_accuracy: 0.9524 - val_loss: 0.3158
# Epoch 227/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9392 - loss: 0.2120 - val_accuracy: 0.9524 - val_loss: 0.3166
# Epoch 228/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9111 - loss: 0.3375 - val_accuracy: 0.9524 - val_loss: 0.3011
# Epoch 229/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9161 - loss: 0.3064 - val_accuracy: 0.9524 - val_loss: 0.3182
# Epoch 230/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9141 - loss: 0.2958 - val_accuracy: 0.9524 - val_loss: 0.3175
# Epoch 231/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8583 - loss: 0.4452 - val_accuracy: 0.9524 - val_loss: 0.3131
# Epoch 232/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8753 - loss: 0.3714 - val_accuracy: 0.9524 - val_loss: 0.3175
# Epoch 233/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9139 - loss: 0.3785 - val_accuracy: 0.9524 - val_loss: 0.3158
# Epoch 234/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8792 - loss: 0.3478 - val_accuracy: 0.9524 - val_loss: 0.3126
# Epoch 235/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8725 - loss: 0.3439 - val_accuracy: 0.9524 - val_loss: 0.3164
# Epoch 236/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9184 - loss: 0.2568 - val_accuracy: 0.9524 - val_loss: 0.3324
# Epoch 237/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9026 - loss: 0.2417 - val_accuracy: 0.9524 - val_loss: 0.3313
# Epoch 238/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8952 - loss: 0.3095 - val_accuracy: 0.9524 - val_loss: 0.3016
# Epoch 239/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8738 - loss: 0.3199 - val_accuracy: 0.9524 - val_loss: 0.3169
# Epoch 240/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9069 - loss: 0.2720 - val_accuracy: 0.9524 - val_loss: 0.3092
# Epoch 241/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8603 - loss: 0.4523 - val_accuracy: 0.9524 - val_loss: 0.3143
# Epoch 242/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9083 - loss: 0.2976 - val_accuracy: 0.9524 - val_loss: 0.3098
# Epoch 243/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9005 - loss: 0.2530 - val_accuracy: 0.9524 - val_loss: 0.3212
# Epoch 244/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8784 - loss: 0.3521 - val_accuracy: 0.9524 - val_loss: 0.3173
# Epoch 245/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9050 - loss: 0.3272 - val_accuracy: 0.9524 - val_loss: 0.3311
# Epoch 246/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8560 - loss: 0.4263 - val_accuracy: 0.9524 - val_loss: 0.3230
# Epoch 247/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8973 - loss: 0.3158 - val_accuracy: 0.9524 - val_loss: 0.3187
# Epoch 248/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9375 - loss: 0.2213 - val_accuracy: 0.9524 - val_loss: 0.3194
# Epoch 249/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9184 - loss: 0.2453 - val_accuracy: 0.9524 - val_loss: 0.3272
# Epoch 250/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9008 - loss: 0.3298 - val_accuracy: 0.9524 - val_loss: 0.3102
# Epoch 251/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8868 - loss: 0.3076 - val_accuracy: 0.9524 - val_loss: 0.2944
# Epoch 252/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8858 - loss: 0.3436 - val_accuracy: 0.9524 - val_loss: 0.3084
# Epoch 253/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8603 - loss: 0.4932 - val_accuracy: 0.9524 - val_loss: 0.3253
# Epoch 254/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8695 - loss: 0.4255 - val_accuracy: 0.9524 - val_loss: 0.3018
# Epoch 255/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8663 - loss: 0.3506 - val_accuracy: 0.9524 - val_loss: 0.3013
# Epoch 256/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8852 - loss: 0.3661 - val_accuracy: 0.9524 - val_loss: 0.3050
# Epoch 257/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8556 - loss: 0.4575 - val_accuracy: 0.9524 - val_loss: 0.3085
# Epoch 258/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9219 - loss: 0.2528 - val_accuracy: 0.9524 - val_loss: 0.3058
# Epoch 259/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9040 - loss: 0.3319 - val_accuracy: 0.9524 - val_loss: 0.3180
# Epoch 260/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8810 - loss: 0.3490 - val_accuracy: 0.9524 - val_loss: 0.3064
# Epoch 261/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8919 - loss: 0.3410 - val_accuracy: 0.9524 - val_loss: 0.3130
# Epoch 262/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8933 - loss: 0.2979 - val_accuracy: 0.9524 - val_loss: 0.3124
# Epoch 263/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8816 - loss: 0.3361 - val_accuracy: 0.9524 - val_loss: 0.3037
# Epoch 264/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9030 - loss: 0.3107 - val_accuracy: 0.9524 - val_loss: 0.3052
# Epoch 265/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9404 - loss: 0.2680 - val_accuracy: 0.9524 - val_loss: 0.3035
# Epoch 266/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9089 - loss: 0.3077 - val_accuracy: 0.9524 - val_loss: 0.3147
# Epoch 267/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8971 - loss: 0.3676 - val_accuracy: 0.9524 - val_loss: 0.3245
# Epoch 268/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9219 - loss: 0.3047 - val_accuracy: 0.9524 - val_loss: 0.3125
# Epoch 269/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8826 - loss: 0.3349 - val_accuracy: 0.9524 - val_loss: 0.3194
# Epoch 270/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9241 - loss: 0.2773 - val_accuracy: 0.9524 - val_loss: 0.3373
# Epoch 271/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8663 - loss: 0.3981 - val_accuracy: 0.9524 - val_loss: 0.3258
# Epoch 272/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8802 - loss: 0.4438 - val_accuracy: 0.9524 - val_loss: 0.3222
# Epoch 273/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8565 - loss: 0.5286 - val_accuracy: 0.9524 - val_loss: 0.3256
# Epoch 274/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8822 - loss: 0.3895 - val_accuracy: 0.9524 - val_loss: 0.3228
# Epoch 275/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9121 - loss: 0.2395 - val_accuracy: 0.9524 - val_loss: 0.3130
# Epoch 276/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8964 - loss: 0.3649 - val_accuracy: 0.9524 - val_loss: 0.3168
# Epoch 277/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8803 - loss: 0.3434 - val_accuracy: 0.9524 - val_loss: 0.3168
# Epoch 278/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8842 - loss: 0.3477 - val_accuracy: 0.9524 - val_loss: 0.3077
# Epoch 279/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9422 - loss: 0.2229 - val_accuracy: 0.9524 - val_loss: 0.3140
# Epoch 280/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8866 - loss: 0.3022 - val_accuracy: 0.9524 - val_loss: 0.3122
# Epoch 281/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9227 - loss: 0.2499 - val_accuracy: 0.9524 - val_loss: 0.3003
# Epoch 282/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8577 - loss: 0.4676 - val_accuracy: 0.9524 - val_loss: 0.3122
# Epoch 283/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9342 - loss: 0.2747 - val_accuracy: 0.9524 - val_loss: 0.3067
# Epoch 284/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8576 - loss: 0.4135 - val_accuracy: 0.9524 - val_loss: 0.3139
# Epoch 285/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9037 - loss: 0.2722 - val_accuracy: 0.9524 - val_loss: 0.3044
# Epoch 286/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8902 - loss: 0.3693 - val_accuracy: 0.9524 - val_loss: 0.3088
# Epoch 287/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9326 - loss: 0.3014 - val_accuracy: 0.9524 - val_loss: 0.3261
# Epoch 288/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9032 - loss: 0.3310 - val_accuracy: 0.9365 - val_loss: 0.3245
# Epoch 289/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8645 - loss: 0.4322 - val_accuracy: 0.9365 - val_loss: 0.3325
# Epoch 290/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9038 - loss: 0.3353 - val_accuracy: 0.9524 - val_loss: 0.3199
# Epoch 291/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9379 - loss: 0.1839 - val_accuracy: 0.9524 - val_loss: 0.3178
# Epoch 292/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9150 - loss: 0.2157 - val_accuracy: 0.9524 - val_loss: 0.3438
# Epoch 293/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9206 - loss: 0.3120 - val_accuracy: 0.9524 - val_loss: 0.3059
# Epoch 294/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9197 - loss: 0.3451 - val_accuracy: 0.9524 - val_loss: 0.3023
# Epoch 295/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8480 - loss: 0.5392 - val_accuracy: 0.9524 - val_loss: 0.3130
# Epoch 296/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8769 - loss: 0.4340 - val_accuracy: 0.9524 - val_loss: 0.2946
# Epoch 297/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9262 - loss: 0.2634 - val_accuracy: 0.9524 - val_loss: 0.3075
# Epoch 298/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8825 - loss: 0.3692 - val_accuracy: 0.9524 - val_loss: 0.3174
# Epoch 299/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9175 - loss: 0.2750 - val_accuracy: 0.9524 - val_loss: 0.2991
# Epoch 300/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8931 - loss: 0.3385 - val_accuracy: 0.9524 - val_loss: 0.3084
# Epoch 301/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8868 - loss: 0.3353 - val_accuracy: 0.9524 - val_loss: 0.3111
# Epoch 302/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9321 - loss: 0.2448 - val_accuracy: 0.9524 - val_loss: 0.3022
# Epoch 303/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9386 - loss: 0.2110 - val_accuracy: 0.9524 - val_loss: 0.3061
# Epoch 304/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9245 - loss: 0.2582 - val_accuracy: 0.9524 - val_loss: 0.3013
# Epoch 305/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8995 - loss: 0.3206 - val_accuracy: 0.9524 - val_loss: 0.2910
# Epoch 306/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8800 - loss: 0.3145 - val_accuracy: 0.9524 - val_loss: 0.3122
# Epoch 307/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9316 - loss: 0.2279 - val_accuracy: 0.9524 - val_loss: 0.3156
# Epoch 308/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9061 - loss: 0.3668 - val_accuracy: 0.9524 - val_loss: 0.2916
# Epoch 309/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9364 - loss: 0.2762 - val_accuracy: 0.9524 - val_loss: 0.2931
# Epoch 310/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8849 - loss: 0.3315 - val_accuracy: 0.9524 - val_loss: 0.2920
# Epoch 311/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9316 - loss: 0.2516 - val_accuracy: 0.9524 - val_loss: 0.3078
# Epoch 312/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9242 - loss: 0.2917 - val_accuracy: 0.9524 - val_loss: 0.3068
# Epoch 313/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9166 - loss: 0.2300 - val_accuracy: 0.9524 - val_loss: 0.3030
# Epoch 314/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9110 - loss: 0.2685 - val_accuracy: 0.9524 - val_loss: 0.2910
# Epoch 315/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8932 - loss: 0.3019 - val_accuracy: 0.9524 - val_loss: 0.3066
# Epoch 316/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8983 - loss: 0.3133 - val_accuracy: 0.9524 - val_loss: 0.3024
# Epoch 317/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8267 - loss: 0.4978 - val_accuracy: 0.9524 - val_loss: 0.2982
# Epoch 318/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9398 - loss: 0.2415 - val_accuracy: 0.9524 - val_loss: 0.2964
# Epoch 319/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8503 - loss: 0.5070 - val_accuracy: 0.9524 - val_loss: 0.3119
# Epoch 320/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9200 - loss: 0.2801 - val_accuracy: 0.9524 - val_loss: 0.3093
# Epoch 321/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9227 - loss: 0.2680 - val_accuracy: 0.9524 - val_loss: 0.3016
# Epoch 322/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9240 - loss: 0.2799 - val_accuracy: 0.9524 - val_loss: 0.2969
# Epoch 323/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8799 - loss: 0.3124 - val_accuracy: 0.9524 - val_loss: 0.2836
# Epoch 324/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.8923 - loss: 0.3332 - val_accuracy: 0.9524 - val_loss: 0.2922
# Epoch 325/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9073 - loss: 0.3080 - val_accuracy: 0.9524 - val_loss: 0.3186
# Epoch 326/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9044 - loss: 0.2730 - val_accuracy: 0.9524 - val_loss: 0.2994
# Epoch 327/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9201 - loss: 0.2464 - val_accuracy: 0.9524 - val_loss: 0.3004
# Epoch 328/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9252 - loss: 0.2316 - val_accuracy: 0.9524 - val_loss: 0.3085
# Epoch 329/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9451 - loss: 0.2323 - val_accuracy: 0.9524 - val_loss: 0.2930
# Epoch 330/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9272 - loss: 0.2828 - val_accuracy: 0.9524 - val_loss: 0.2923
# Epoch 331/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9287 - loss: 0.1652 - val_accuracy: 0.9524 - val_loss: 0.3103
# Epoch 332/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9220 - loss: 0.2226 - val_accuracy: 0.9524 - val_loss: 0.3034
# Epoch 333/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9123 - loss: 0.2437 - val_accuracy: 0.9524 - val_loss: 0.2989
# Epoch 334/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9427 - loss: 0.2007 - val_accuracy: 0.9524 - val_loss: 0.3142
# Epoch 335/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8648 - loss: 0.3573 - val_accuracy: 0.9524 - val_loss: 0.3103
# Epoch 336/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9222 - loss: 0.2358 - val_accuracy: 0.9524 - val_loss: 0.3045
# Epoch 337/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9157 - loss: 0.2516 - val_accuracy: 0.9524 - val_loss: 0.3137
# Epoch 338/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9204 - loss: 0.2443 - val_accuracy: 0.9524 - val_loss: 0.3322
# Epoch 339/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9233 - loss: 0.2790 - val_accuracy: 0.9524 - val_loss: 0.3041
# Epoch 340/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9268 - loss: 0.2736 - val_accuracy: 0.9524 - val_loss: 0.2947
# Epoch 341/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9329 - loss: 0.2451 - val_accuracy: 0.9524 - val_loss: 0.3003
# Epoch 342/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8162 - loss: 0.6005 - val_accuracy: 0.9524 - val_loss: 0.3031
# Epoch 343/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8613 - loss: 0.3805 - val_accuracy: 0.9524 - val_loss: 0.3079
# Epoch 344/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9016 - loss: 0.2570 - val_accuracy: 0.9524 - val_loss: 0.2959
# Epoch 345/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9061 - loss: 0.3104 - val_accuracy: 0.9524 - val_loss: 0.3073
# Epoch 346/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9402 - loss: 0.2210 - val_accuracy: 0.9524 - val_loss: 0.3113
# Epoch 347/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9467 - loss: 0.2220 - val_accuracy: 0.9524 - val_loss: 0.2978
# Epoch 348/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8930 - loss: 0.3014 - val_accuracy: 0.9524 - val_loss: 0.3120
# Epoch 349/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9335 - loss: 0.2135 - val_accuracy: 0.9524 - val_loss: 0.2961
# Epoch 350/350
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8987 - loss: 0.2923 - val_accuracy: 0.9524 - val_loss: 0.2902

# %%
# Step 9: Save model + words/classes + training history
model.save('ds_chatbot_model.h5')
pickle.dump({
    'words': words,
    'classes': classes,
    'history': history.history
}, open('ds_chatbot_data.pkl', 'wb'))

print("Model saved to 'ds_chatbot_model.h5' and data saved to 'chatbot_data.pkl'")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved to 'ds_chatbot_model.h5' and data saved to 'chatbot_data.pkl'

# %%
# Step 10: plot history (accuracy/loss)
pd.DataFrame(history.history).plot()
plt.title("Training history")
plt.xlabel("Epoch")
plt.grid(True)
plt.show()

# %%
#Classes.pkl file

# %%
import json
import pickle

# ---------------------------
# 1. Load job_intents.json
# ---------------------------
with open(data_path, "r", encoding="utf-8") as f:
    intents = json.load(f)

# %%
# ---------------------------
# 2. Extract unique classes (tags)
# ---------------------------
classes = []

for intent in intents.get("intents", []):
    tag = intent.get("tag")
    if tag and tag not in classes:
        classes.append(tag)

# Sort classes
classes = sorted(classes)

print("Total classes found:", len(classes))
print(classes)
# Out:
# Total classes found: 102
# ['a/b_testing', 'acf/pacf', 'anomaly_detection', 'anova', 'arima', 'attention_mechanism', 'automl', 'bag_of_words', 'bayesian_optimization', 'bayesian_statistics', 'bert', 'bias-variance_tradeoff', 'big_data_concepts', 'catboost', 'chi-square_test', 'clustering', 'convolutional_neural_networks', 'correlation_analysis', 'cross-validation', 'dashboards', 'data_pipelines', 'data_visualization', 'data_warehousing', 'dbscan', 'decision_trees', 'deep_learning', 'deep_q_networks', 'docker_for_ml', 'elastic_net', 'ensemble_methods', 'etl_processes', 'ets_models', 'experiment_tracking', 'fastapi_for_ml', 'feature_engineering', 'feature_selection', 'flask_for_ml', 'glove', 'gpt_models', 'gradient_boosting', 'greeting', 'grid_search', 'grus', 'hadoop', 'hierarchical_clustering', 'hyperparameter_tuning', 'hypothesis_testing', 'k-means', 'k-nearest_neighbors', 'l1_regularization', 'l2_regularization', 'lightgbm', 'lime', 'linear_regression', 'logistic_regression', 'lstms', 'mapreduce', 'matplotlib', 'mlflow', 'mlops', 'model_deployment', 'model_drift_detection', 'model_explainability', 'model_monitoring', 'naive_bayes', 'natural_language_processing', 'neural_networks', 'normalization', 'nosql_basics', 'outlier_detection', 'pca', 'plotly', 'policy_gradient_methods', 'power_bi', 'probability_distributions', 'q-learning', 'random_forests', 'random_search', 'recurrent_neural_networks', 'redshift', 'regularization', 'reinforcement_learning', 'sarima', 'seaborn', 'seasonality_detection', 'shap_values', 'snowflake', 'spark', 'sql_for_data_science', 'standardization', 'stationarity_testing', 'support_vector_machines', 't-sne', 'tableau', 'tf-idf', 'time_series_analysis', 'tokenization', 'transformers', 'umap', 'word2vec', 'word_embeddings', 'xgboost']

# %%
# ---------------------------
# 3. Save classes.pkl
# ---------------------------
with open("classes.pkl", "wb") as f:
    pickle.dump(classes, f)

print("\nclasses.pkl file successfully created!")
# Out:
# classes.pkl file successfully created!

# %%
#word.pkl file

# %%
import json
import pickle
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

# Download required NLTK models (first time only)
nltk.download('punkt')
nltk.download('wordnet')

# --------------------------------------
# 1. Load job_intents.json
# --------------------------------------
with open(data_path, "r", encoding="utf-8") as f:
    intents = json.load(f)

# --------------------------------------
# 2. Preprocessing setup
# --------------------------------------
lemmatizer = WordNetLemmatizer()
ignore_words = ['?', '!', '.', ',']

words = []        # vocabulary list
documents = []    # (pattern, tag) pairs

# --------------------------------------
# 3. Tokenize, lemmatize & collect words
# --------------------------------------
for intent in intents["intents"]:
    for pattern in intent["patterns"]:
        tokens = word_tokenize(pattern)               # tokenize
        words.extend(tokens)                          # add tokens
        documents.append((tokens, intent["tag"]))     # store structure

# --------------------------------------
# 4. Clean words → lower, lemmatize, remove symbols
# --------------------------------------
words = [lemmatizer.lemmatize(w.lower())
         for w in words
         if w not in ignore_words]

# unique + sorted
words = sorted(list(set(words)))

print("Total unique words:", len(words))
print(words[:50])   # first 50 words preview

# --------------------------------------
# 5. Save words.pkl
# --------------------------------------
with open("words.pkl", "wb") as f:
    pickle.dump(words, f)

print("\nwords.pkl successfully created!")
# Out:
# Total unique words: 157
# ['a/b', 'about', 'acf/pacf', 'analysis', 'anomaly', 'anova', 'anyone', 'are', 'arima', 'attention', 'automl', 'bag', 'basic', 'bayes', 'bayesian', 'bert', 'bi', 'bias-variance', 'big', 'boosting', 'catboost', 'chi-square', 'clustering', 'concept', 'convolutional', 'correlation', 'cross-validation', 'dashboard', 'data', 'day', 'dbscan', 'decision', 'deep', 'deployment', 'detection', 'distribution', 'docker', 'drift', 'ekse', 'elastic', 'embeddings', 'engineering', 'ensemble', 'etl', 'ets', 'experiment', 'explain', 'explainability', 'fastapi', 'feature']
#
# words.pkl successfully created!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
